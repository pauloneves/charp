# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.style.use('./paulo.mplstyle')

# %%
df = sns.load_dataset('iris')

# %%
dfg = df.groupby('species').mean()
dfg
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
fig = plt.figure()
ax = fig.gca()
plt.hist(df.query('species=="virginica"').petal_length)
ax.set_title("Maria vai com as outras")
ax.yaxis.get_label()
# Out:
# Text(0, 0.5, '')

# %%
ax = df.plot.line();

# %%
[line.get_label() for line in ax.lines]
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
dir(ax.lines[0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_callbacks',
#  '_clipon',
#  '_clippath',
#  '_color',
#  '_contains',
#  '_dashOffset',
#  '_dashSeq',
#  '_dashcapstyle',
#  '_dashjoinstyle',
#  '_default_contains',
#  '_drawStyles_l',
#  '_drawStyles_s',
#  '_drawstyle',
#  '_get_clipping_extent_bbox',
#  '_get_markerfacecolor',
#  '_get_transformed_path',
#  '_gid',
#  '_in_layout',
#  '_invalidx',
#  '_invalidy',
#  '_is_sorted',
#  '_label',
#  '_lineStyles',
#  '_linestyle',
#  '_linestyles',
# ...

# %%
import numpy as np

def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 3, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    ax[0].set_title("Meu título")
    ax[0].set_xlabel("Valores de X título")
    ax[0].set_ylabel("Y Values")
    ax[0].axhline(150)
    import string
    num_lines = 4
    for i in range(num_lines):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(string.ascii_letters[:num_lines], loc='lower left')
    
    num_bars = 6
    bars = [4 + 10 * np.random.rand() for _ in range(num_bars)]
    ax[2].bar(np.arange(num_bars), bars)
    #ax[2].set_title("Barras codificadas")
    
                   
hist_and_lines()

# %%
plt.style.use('./paulo.mplstyle')
hist_and_lines()

# %% [markdown]
# # **CHAR**ts for **P**aulo

# %%
import charp

# %% [markdown]
# ## Titles
#
# Aligning axes titles over Y labels

# %%
ax= charp.example_chart()
charp.set_title("MMMM", ax=ax)
# Out:
# Text(-0.06923536439665472, 1.01, 'MMMM')

# %% [markdown]
# ## Horizontal Bars

# %%
def barh():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(15, 3))
    num_bars = 6
    bars = [20 * np.random.rand() for _ in range(num_bars)]
    ax[0].barh(np.arange(num_bars), bars)
    charp.set_title("Horizontal Bars", ax=ax[0])
    multi_words = ("ipsulum lorem " * 10).split()
    labels = [' '.join(multi_words[:i+1]).strip() for i in np.arange(num_bars)]
    ax[1].barh(y=np.arange(num_bars), width=bars)
    ax[1].set_yticks(np.arange(num_bars))
    ax[1].set_yticklabels(labels)
    charp.barh(break_lines=True, ax=ax[1])
    charp.set_title("Horizontal Bars Fixed", ax=ax[1])
    
plt.style.use('./paulo.mplstyle')    
barh()

# %% [markdown]
# ## Vertical bars

# %%
def bar():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(15, 3))
    num_bars = 6
    bars = [20 * np.random.rand() for _ in range(num_bars)]
    ax[0].bar(np.arange(num_bars), bars)
    ax[0].set_title("Vertical Bars")
    ax[1].bar(np.arange(num_bars), bars)
    charp.set_title("Vertical Bars Fixed", ax=ax[1])
    charp.bar(ax[1])
plt.style.use('./paulo.mplstyle')    
bar()

# %% [markdown]
# ## Lines

# %%
df = sns.load_dataset('iris')
df.shape
# Out:
# (150, 5)

# %%
def line():
    df = sns.load_dataset('iris')
    df.iloc[df.shape[0]//2 - 20:, 0] = np.NaN
    fig, ax = plt.subplots(1, 2, figsize=(15, 3))
    df.plot.line(ax=ax[0]); # iris dataset
    charp.set_title("Standard lines", ax=ax[0])

    df.plot.line(ax=ax[1]); # iris dataset
    charp.line(ax[1])
    charp.set_title("Better lines", ax=ax[1])
plt.style.use('./paulo.mplstyle')    
line()

# %% [markdown]
# ## Tests backup

# %%
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': '.8',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
plt.style.use('./paulo.mplstyle')
colors = plt.rcParams['axes.prop_cycle']# create a dataset
c = [i['color'] for i in colors]
height = [10] * len(c)
bars = c
x_pos = np.arange(len(bars))

# Create bars with different colors
plt.bar(x_pos, height, color=c)
# Out:
# <BarContainer object of 7 artists>

# %%
pd.DataFrame(data=[10] * len(colors), index=colors).plot.barh(color=[i['color'] for i in colors])
# Out:
# <AxesSubplot:>

# %%
[i['color'] for i in colors]
# Out:
# ['#b3cde3', '#e5d8bd', '#ccebc5', '#decbe4', '#fed9a6', '#ffffcc', '#fbb4ae']

# %% [markdown]
# ## Clean font cache and check installed fonts

# %%
import shutil
import matplotlib

shutil.rmtree(matplotlib.get_cachedir())

# %%
import matplotlib.font_manager
from IPython.core.display import HTML

def make_html(fontname):
    return "<p>{font}: <span style='font-family:{font}; font-size: 24px;'>{font}</p>".format(font=fontname)

code = "\n".join([make_html(font) for font in sorted(set([f.name for f in matplotlib.font_manager.fontManager.ttflist]))])

HTML("<div style='column-count: 2;'>{}</div>".format(code))
# Out:
# <div style='column-count: 2;'><p>DejaVu Math TeX Gyre: <span style='font-family:DejaVu Math TeX Gyre; font-size: 24px;'>DejaVu Math TeX Gyre</p>
# <p>DejaVu Sans: <span style='font-family:DejaVu Sans; font-size: 24px;'>DejaVu Sans</p>
# <p>DejaVu Sans Display: <span style='font-family:DejaVu Sans Display; font-size: 24px;'>DejaVu Sans Display</p>
# <p>DejaVu Sans Mono: <span style='font-family:DejaVu Sans Mono; font-size: 24px;'>DejaVu Sans Mono</p>
# <p>DejaVu Serif: <span style='font-family:DejaVu Serif; font-size: 24px;'>DejaVu Serif</p>
# <p>DejaVu Serif Display: <span style='font-family:DejaVu Serif Display; font-size: 24px;'>DejaVu Serif Display</p>
# <p>Roboto: <span style='font-family:Roboto; font-size: 24px;'>Roboto</p>
# <p>Roboto Condensed: <span style='font-family:Roboto Condensed; font-size: 24px;'>Roboto Condensed</p>
# <p>STIXGeneral: <span style='font-family:STIXGeneral; font-size: 24px;'>STIXGeneral</p>
# ...
