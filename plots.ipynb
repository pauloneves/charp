# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.style.use('./paulo.mplstyle')

# %%
df = sns.load_dataset('iris')

# %%
dfg = df.groupby('species').mean()
dfg
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
fig = plt.figure()
ax = fig.gca()
plt.hist(df.query('species=="virginica"').petal_length)
ax.set_title("Maria vai com as outras")
ax.yaxis.get_label()
# Out:
# Text(0, 0.5, '')

# %%
df.plot.line()
# Out:
# <AxesSubplot:>

# %%
import numpy as np

def hist_and_lines():
    np.random.seed(0)
    fig, ax = plt.subplots(1, 2, figsize=(11, 4))
    ax[0].hist(np.random.randn(1000))
    for i in range(3):
        ax[1].plot(np.random.rand(10))
    ax[1].legend(['a', 'b', 'c'], loc='lower left')
    ax[0].set_title("Meu título")
    ax[0].set_xlabel("Valores de X")
    ax[0].set_ylabel("Y Values")
hist_and_lines()

# %%
plt.style.use('./paulo.mplstyle')
hist_and_lines()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4847/758932051.py in <module>
#       1 plt.style.use('./paulo.mplstyle')
# ----> 2 hist_and_line()
#
# NameError: name 'hist_and_line' is not defined

# %%
import matplotlib
matplotlib.matplotlib_fname()
# Out:
# '/home/neves/miniconda3/envs/datascience/lib/python3.8/site-packages/matplotlib/mpl-data/matplotlibrc'

# %% [markdown]
# ## Tests backup

# %%
custom_params = {
    "axes.spines.right": False, 
    "axes.spines.top": False, 
    "axes.spines.left": False, 
    'grid.color': '.95',
    'figure.dpi': 150,
    'axes.labelcolor': '.5',
    'legend.framealpha': 1,
    'legend.frameon': False,
}
sns.set_theme(style="whitegrid", palette="pastel", rc=custom_params)
hist_and_lines()

# %%
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.avconv_args': [],
#           'animation.avconv_path': 'avconv',
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.html_args': [],
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': True,
#           'axes.edgecolor': '.8',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
# ...

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']
